# %%
#!pip install pymongo

# %%
import pymongo
from pymongo import MongoClient
import pprint

# %%
CONNECTION_STRING = "mongodb+srv://longth:asdQWE123@cluster0.tehe2.azure.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(CONNECTION_STRING)

# %%
client.list_database_names()
# Out:
# ['Data_Engineer', 'video', 'admin', 'local']

# %%
db = client['Data_Engineer']

# %%
database = client.Data_Engineer

# %%
database.list_collection_names()
# Out:
# ['Customer_Registered', 'Comments']

# %%
collection = db["Customer_Registered"]

# %%
cursor = collection.find()

# %%
list_cur = list(cursor)

# %%
list_cur
# Out:
# [{'_id': ObjectId('626a06b65e05207c51b2c083'),
#   'status': 1,
#   'user_id': 9587152,
#   'name': 'mach tung chau',
#   'mp_expire_time': {'box_maxvip_01042022': 1658615702},
#   'device_model': 'FPT Play Box +',
#   'address': '445 Huỳnh Tấn Phát, Tân Thuận Đông, Quận 7, Thành phố Hồ Chí Minh, Việt Nam',
#   'market_plan': ['box_maxvip_01042022'],
#   'device_name': 'FPT Play Box (version:10,model:FPT Play Box +)',
#   'plan_ids': [3736],
#   'platform': 'fplay-ottbox-sdmc-2020',
#   'mp_join_time': {'box_maxvip_01042022': 1651115702},
#   'created_date': datetime.datetime(2022, 4, 28, 10, 15, 2, 256000),
#   'mac_address': 'FC:D5:D9:4E:0C:79'},
#  {'_id': ObjectId('626a06d05e05207c53b2c083'),
#   'status': 1,
#   'user_id': 14124037,
#   'name': 'giauvo',
#   'mp_expire_time': {'box_maxvip_01042022': 1658615728},
#   'device_model': 'FPT Play Box S',
#   'address': '22 Cô Bắc, P. Mỹ Bình, Thành phố Long Xuyên, An Giang, Việt Nam',
#   'market_plan': ['box_maxvip_01042022'],
# ...

# %%
list(collection.find({"device_model" : "FPT Play Box +"}))
# Out:
# [{'_id': ObjectId('626a06b65e05207c51b2c083'),
#   'status': 1,
#   'user_id': 9587152,
#   'name': 'mach tung chau',
#   'mp_expire_time': {'box_maxvip_01042022': 1658615702},
#   'device_model': 'FPT Play Box +',
#   'address': '445 Huỳnh Tấn Phát, Tân Thuận Đông, Quận 7, Thành phố Hồ Chí Minh, Việt Nam',
#   'market_plan': ['box_maxvip_01042022'],
#   'device_name': 'FPT Play Box (version:10,model:FPT Play Box +)',
#   'plan_ids': [3736],
#   'platform': 'fplay-ottbox-sdmc-2020',
#   'mp_join_time': {'box_maxvip_01042022': 1651115702},
#   'created_date': datetime.datetime(2022, 4, 28, 10, 15, 2, 256000),
#   'mac_address': 'FC:D5:D9:4E:0C:79'},
#  {'_id': ObjectId('626a07325e05207c4db2c084'),
#   'status': 1,
#   'user_id': 28164249,
#   'name': 'le huy',
#   'mp_expire_time': {'box_maxvip_01042022': 1658615826},
#   'device_model': 'FPT Play Box +',
#   'address': 'phu',
#   'market_plan': ['box_maxvip_01042022'],
# ...

# %%
import pandas as pd
# convert the dictionary objects to dataframe
items_df = pd.DataFrame(list_cur)

# %%
items_df
# Out:
#                            _id  status   user_id               name  \
# 0     626a06b65e05207c51b2c083       1   9587152     mach tung chau
# 1     626a06d05e05207c53b2c083       1  14124037             giauvo
# 2     626a06f45e05207c4db2c083       1   8124383                 vu
# 3     626a06f45e05207c51b2c084       1   2192124     dang binh minh
# 4     626a07325e05207c4db2c084       1  28164249             le huy
# ...                        ...     ...       ...                ...
# 8968  634cff955e0520037cb14172       1  29311531       nguyenkimhoc
# 8969  634d08db5e0520037fb14151       1  23585024  ta THI HONG PHUNG
# 8970  634d4b1e5e0520037eb14224       1  27420954          vu van ut
# 8971  634d75ed5e0520037fb1416f       1  23353222       VU THANH NAM
# 8972  634d78fe5e0520037cb1419a       1  27939155               tuan
#
#                            mp_expire_time      device_model  \
# 0     {'box_maxvip_01042022': 1658615702}    FPT Play Box +
# ...

# %%
items_df['created_date_dateonly'] = pd.to_datetime(items_df['created_date']).dt.date

# %%
result = items_df[['created_date_dateonly','_id']].groupby(['created_date_dateonly']).count()

# %%
result = result.reset_index()

# %%
result.rename(columns={'created_date_dateonly':'Date','_id':'TotalUser'},inplace=True)

# %%
result.head()
# Out:
#          Date  TotalUser
# 0  2022-04-28        962
# 1  2022-05-17        681
# 2  2022-05-18        826
# 3  2022-05-19        528
# 4  2022-05-20        300
